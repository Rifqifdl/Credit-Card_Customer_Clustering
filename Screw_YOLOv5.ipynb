# %% [markdown]
# <a href="https://colab.research.google.com/github/Rifqifdl/Credit-Card_Customer_Clustering/blob/main/Screw_YOLOv5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <div align="center">
#
#   <a href="https://ultralytics.com/yolov5" target="_blank">
#     <img width="1024", src="https://raw.githubusercontent.com/ultralytics/assets/main/yolov5/v70/splash.png"></a>
#
# [中文](https://docs.ultralytics.com/zh/) | [한국어](https://docs.ultralytics.com/ko/) | [日本語](https://docs.ultralytics.com/ja/) | [Русский](https://docs.ultralytics.com/ru/) | [Deutsch](https://docs.ultralytics.com/de/) | [Français](https://docs.ultralytics.com/fr/) | [Español](https://docs.ultralytics.com/es/) | [Português](https://docs.ultralytics.com/pt/) | [हिन्दी](https://docs.ultralytics.com/hi/) | [العربية](https://docs.ultralytics.com/ar/)
#
#   <a href="https://bit.ly/yolov5-paperspace-notebook"><img src="https://assets.paperspace.io/img/gradient-badge.svg" alt="Run on Gradient"></a>
#   <a href="https://colab.research.google.com/github/ultralytics/yolov5/blob/master/tutorial.ipynb"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"></a>
#   <a href="https://www.kaggle.com/ultralytics/yolov5"><img src="https://kaggle.com/static/images/open-in-kaggle.svg" alt="Open In Kaggle"></a>
#
# This <a href="https://github.com/ultralytics/yolov5">YOLOv5</a> 🚀 notebook by <a href="https://ultralytics.com">Ultralytics</a> presents simple train, validate and predict examples to help start your AI adventure.<br>We hope that the resources in this notebook will help you get the most out of YOLOv5. Please browse the YOLOv5 <a href="https://docs.ultralytics.com/yolov5">Docs</a> for details, raise an issue on <a href="https://github.com/ultralytics/yolov5">GitHub</a> for support, and join our <a href="https://ultralytics.com/discord">Discord</a> community for questions and discussions!
#
# </div>

# %% [markdown]
# # Setup
#
# Clone GitHub [repository](https://github.com/ultralytics/yolov5), install [dependencies](https://github.com/ultralytics/yolov5/blob/master/requirements.txt) and check PyTorch and GPU.

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone
# %cd yolov5
# %pip install -qr requirements.txt comet_ml  # install

import torch
import utils
display = utils.notebook_init()  # checks
# Out:
# YOLOv5 🚀 v7.0-247-g3f02fde Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 27.0/78.2 GB disk)

# %%
# !unzip -q /content/screw-dataset.zip -d ../

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # 1. Detect
#
# `detect.py` runs YOLOv5 inference on a variety of sources, downloading models automatically from the [latest YOLOv5 release](https://github.com/ultralytics/yolov5/releases), and saving results to `runs/detect`. Example inference sources are:
#
# ```shell
# python detect.py --source 0  # webcam
#                           img.jpg  # image
#                           vid.mp4  # video
#                           screen  # screenshot
#                           path/  # directory
#                          'path/*.jpg'  # glob
#                          'https://youtu.be/LNwODJXcvt4'  # YouTube
#                          'rtsp://example.com/media.mp4'  # RTSP, RTMP, HTTP stream
# ```

# %%
# !python detect.py --weights runs/train/exp2/weights/best.pt --img 640 --conf 0.25 --source ../sekrup.mp4
# display.Image(filename='runs/detect/exp/zidane.jpg', width=600)
# Out:
# detect: weights=['runs/train/exp2/weights/best.pt'], source=../sekrup.mp4, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-247-g3f02fde Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# video 1/1 (1/424) /content/sekrup.mp4: 640x384 4 Screws, 42.0ms
# video 1/1 (2/424) /content/sekrup.mp4: 640x384 4 Screws, 9.8ms
# video 1/1 (3/424) /content/sekrup.mp4: 640x384 3 Screws, 9.5ms
# video 1/1 (4/424) /content/sekrup.mp4: 640x384 3 Screws, 9.8ms
# video 1/1 (5/424) /content/sekrup.mp4: 640x384 4 Screws, 9.2ms
# video 1/1 (6/424) /content/sekrup.mp4: 640x384 4 Screws, 9.1ms
# video 1/1 (7/424) /content/sekrup.mp4: 640x384 4 Screws, 10.0ms
# video 1/1 (8/424) /content/sekrup.mp4: 640x384 4 Screws, 9.9ms
# video 1/1 (9/424) /content/sekrup.mp4: 640x384 4 Screws, 9.4ms
# video 1/1 (10/424) /content/sekrup.mp4: 640x384 3 Screws, 10.0ms
# video 1/1 (11/424) /content/sekrup.mp4: 640x384 3 Screws, 9.6ms
# video 1/1 (12/424) /content/sekrup.mp4: 640x384 4 Screws, 10.8ms
# video 1/1 (13/424) /content/sekrup.mp4: 640x384 3 Screws, 9.0ms
# video 1/1 (14/424) /content/sekrup.mp4: 640x384 3 Screws, 9.3ms
# video 1/1 (15/424) /content/sekrup.mp4: 640x384 3 Screws, 9.3ms
# video 1/1 (16/424) /content/sekrup.mp4: 640x384 3 Screws, 9.0ms
# video 1/1 (17/424) /content/sekrup.mp4: 640x384 3 Screws, 8.9ms
# video 1/1 (18/424) /content/sekrup.mp4: 640x384 4 Screws, 9.1ms
# video 1/1 (19/424) /content/sekrup.mp4: 640x384 4 Screws, 9.3ms
# video 1/1 (20/424) /content/sekrup.mp4: 640x384 4 Screws, 9.8ms
# video 1/1 (21/424) /content/sekrup.mp4: 640x384 3 Screws, 9.6ms
# video 1/1 (22/424) /content/sekrup.mp4: 640x384 4 Screws, 9.5ms
# video 1/1 (23/424) /content/sekrup.mp4: 640x384 4 Screws, 9.5ms
# video 1/1 (24/424) /content/sekrup.mp4: 640x384 3 Screws, 11.3ms
# video 1/1 (25/424) /content/sekrup.mp4: 640x384 3 Screws, 9.6ms
# video 1/1 (26/424) /content/sekrup.mp4: 640x384 3 Screws, 9.5ms
# video 1/1 (27/424) /content/sekrup.mp4: 640x384 3 Screws, 9.2ms
# video 1/1 (28/424) /content/sekrup.mp4: 640x384 3 Screws, 10.2ms
# video 1/1 (29/424) /content/sekrup.mp4: 640x384 3 Screws, 9.1ms
# video 1/1 (30/424) /content/sekrup.mp4: 640x384 3 Screws, 8.9ms
# video 1/1 (31/424) /content/sekrup.mp4: 640x384 3 Screws, 9.3ms
# video 1/1 (32/424) /content/sekrup.mp4: 640x384 3 Screws, 9.2ms
# video 1/1 (33/424) /content/sekrup.mp4: 640x384 3 Screws, 10.1ms
# video 1/1 (34/424) /content/sekrup.mp4: 640x384 3 Screws, 9.8ms
# video 1/1 (35/424) /content/sekrup.mp4: 640x384 4 Screws, 9.2ms
# video 1/1 (36/424) /content/sekrup.mp4: 640x384 3 Screws, 9.7ms
# video 1/1 (37/424) /content/sekrup.mp4: 640x384 3 Screws, 10.0ms
# video 1/1 (38/424) /content/sekrup.mp4: 640x384 3 Screws, 10.0ms
# video 1/1 (39/424) /content/sekrup.mp4: 640x384 3 Screws, 9.7ms
# video 1/1 (40/424) /content/sekrup.mp4: 640x384 3 Screws, 9.2ms
# video 1/1 (41/424) /content/sekrup.mp4: 640x384 4 Screws, 9.3ms
# video 1/1 (42/424) /content/sekrup.mp4: 640x384 4 Screws, 8.5ms
# video 1/1 (43/424) /content/sekrup.mp4: 640x384 4 Screws, 9.5ms
# video 1/1 (44/424) /content/sekrup.mp4: 640x384 3 Screws, 9.1ms
# video 1/1 (45/424) /content/sekrup.mp4: 640x384 4 Screws, 9.7ms
# video 1/1 (46/424) /content/sekrup.mp4: 640x384 4 Screws, 8.8ms
# video 1/1 (47/424) /content/sekrup.mp4: 640x384 3 Screws, 10.2ms
# video 1/1 (48/424) /content/sekrup.mp4: 640x384 3 Screws, 9.1ms
# video 1/1 (49/424) /content/sekrup.mp4: 640x384 3 Screws, 9.3ms
# video 1/1 (50/424) /content/sekrup.mp4: 640x384 4 Screws, 9.8ms
# video 1/1 (51/424) /content/sekrup.mp4: 640x384 3 Screws, 9.8ms
# video 1/1 (52/424) /content/sekrup.mp4: 640x384 4 Screws, 9.5ms
# video 1/1 (53/424) /content/sekrup.mp4: 640x384 3 Screws, 10.9ms
# video 1/1 (54/424) /content/sekrup.mp4: 640x384 3 Screws, 9.2ms
# video 1/1 (55/424) /content/sekrup.mp4: 640x384 3 Screws, 10.2ms
# video 1/1 (56/424) /content/sekrup.mp4: 640x384 3 Screws, 10.2ms
# video 1/1 (57/424) /content/sekrup.mp4: 640x384 3 Screws, 9.2ms
# video 1/1 (58/424) /content/sekrup.mp4: 640x384 3 Screws, 9.0ms
# video 1/1 (59/424) /content/sekrup.mp4: 640x384 3 Screws, 9.3ms
# video 1/1 (60/424) /content/sekrup.mp4: 640x384 4 Screws, 8.5ms
# video 1/1 (61/424) /content/sekrup.mp4: 640x384 3 Screws, 8.9ms
# video 1/1 (62/424) /content/sekrup.mp4: 640x384 3 Screws, 9.2ms
# video 1/1 (63/424) /content/sekrup.mp4: 640x384 3 Screws, 9.5ms
# video 1/1 (64/424) /content/sekrup.mp4: 640x384 2 Screws, 9.2ms
# video 1/1 (65/424) /content/sekrup.mp4: 640x384 3 Screws, 9.1ms
# video 1/1 (66/424) /content/sekrup.mp4: 640x384 (no detections), 9.7ms
# video 1/1 (67/424) /content/sekrup.mp4: 640x384 1 Screw, 11.0ms
# video 1/1 (68/424) /content/sekrup.mp4: 640x384 3 Screws, 9.3ms
# video 1/1 (69/424) /content/sekrup.mp4: 640x384 3 Screws, 17.4ms
# video 1/1 (70/424) /content/sekrup.mp4: 640x384 4 Screws, 12.4ms
# video 1/1 (71/424) /content/sekrup.mp4: 640x384 3 Screws, 9.0ms
# video 1/1 (72/424) /content/sekrup.mp4: 640x384 4 Screws, 9.1ms
# video 1/1 (73/424) /content/sekrup.mp4: 640x384 (no detections), 8.8ms
# video 1/1 (74/424) /content/sekrup.mp4: 640x384 3 Screws, 9.0ms
# video 1/1 (75/424) /content/sekrup.mp4: 640x384 1 Screw, 9.3ms
# video 1/1 (76/424) /content/sekrup.mp4: 640x384 (no detections), 8.9ms
# video 1/1 (77/424) /content/sekrup.mp4: 640x384 (no detections), 9.1ms
# video 1/1 (78/424) /content/sekrup.mp4: 640x384 2 Screws, 9.4ms
# video 1/1 (79/424) /content/sekrup.mp4: 640x384 (no detections), 9.5ms
# video 1/1 (80/424) /content/sekrup.mp4: 640x384 3 Screws, 9.5ms
# video 1/1 (81/424) /content/sekrup.mp4: 640x384 3 Screws, 9.2ms
# video 1/1 (82/424) /content/sekrup.mp4: 640x384 4 Screws, 8.9ms
# video 1/1 (83/424) /content/sekrup.mp4: 640x384 3 Screws, 9.0ms
# video 1/1 (84/424) /content/sekrup.mp4: 640x384 3 Screws, 8.8ms
# video 1/1 (85/424) /content/sekrup.mp4: 640x384 2 Screws, 8.8ms
# video 1/1 (86/424) /content/sekrup.mp4: 640x384 1 Screw, 9.0ms
# video 1/1 (87/424) /content/sekrup.mp4: 640x384 (no detections), 8.7ms
# video 1/1 (88/424) /content/sekrup.mp4: 640x384 3 Screws, 9.4ms
# video 1/1 (89/424) /content/sekrup.mp4: 640x384 (no detections), 11.9ms
# video 1/1 (90/424) /content/sekrup.mp4: 640x384 (no detections), 8.4ms
# video 1/1 (91/424) /content/sekrup.mp4: 640x384 4 Screws, 8.9ms
# video 1/1 (92/424) /content/sekrup.mp4: 640x384 1 Screw, 8.9ms
# video 1/1 (93/424) /content/sekrup.mp4: 640x384 3 Screws, 11.1ms
# video 1/1 (94/424) /content/sekrup.mp4: 640x384 3 Screws, 9.0ms
# video 1/1 (95/424) /content/sekrup.mp4: 640x384 (no detections), 9.1ms
# video 1/1 (96/424) /content/sekrup.mp4: 640x384 2 Screws, 9.2ms
# video 1/1 (97/424) /content/sekrup.mp4: 640x384 4 Screws, 11.9ms
# video 1/1 (98/424) /content/sekrup.mp4: 640x384 4 Screws, 9.3ms
# video 1/1 (99/424) /content/sekrup.mp4: 640x384 4 Screws, 10.0ms
# video 1/1 (100/424) /content/sekrup.mp4: 640x384 5 Screws, 9.3ms
# video 1/1 (101/424) /content/sekrup.mp4: 640x384 5 Screws, 9.6ms
# video 1/1 (102/424) /content/sekrup.mp4: 640x384 4 Screws, 10.3ms
# video 1/1 (103/424) /content/sekrup.mp4: 640x384 4 Screws, 9.1ms
# video 1/1 (104/424) /content/sekrup.mp4: 640x384 4 Screws, 8.7ms
# video 1/1 (105/424) /content/sekrup.mp4: 640x384 4 Screws, 9.2ms
# video 1/1 (106/424) /content/sekrup.mp4: 640x384 4 Screws, 9.4ms
# video 1/1 (107/424) /content/sekrup.mp4: 640x384 4 Screws, 9.2ms
# video 1/1 (108/424) /content/sekrup.mp4: 640x384 4 Screws, 14.2ms
# video 1/1 (109/424) /content/sekrup.mp4: 640x384 4 Screws, 9.3ms
# video 1/1 (110/424) /content/sekrup.mp4: 640x384 3 Screws, 9.0ms
# video 1/1 (111/424) /content/sekrup.mp4: 640x384 4 Screws, 8.8ms
# video 1/1 (112/424) /content/sekrup.mp4: 640x384 3 Screws, 9.9ms
# video 1/1 (113/424) /content/sekrup.mp4: 640x384 2 Screws, 9.2ms
# video 1/1 (114/424) /content/sekrup.mp4: 640x384 1 Screw, 9.6ms
# video 1/1 (115/424) /content/sekrup.mp4: 640x384 2 Screws, 8.9ms
# video 1/1 (116/424) /content/sekrup.mp4: 640x384 3 Screws, 9.2ms
# video 1/1 (117/424) /content/sekrup.mp4: 640x384 3 Screws, 8.9ms
# video 1/1 (118/424) /content/sekrup.mp4: 640x384 3 Screws, 8.6ms
# video 1/1 (119/424) /content/sekrup.mp4: 640x384 3 Screws, 8.8ms
# video 1/1 (120/424) /content/sekrup.mp4: 640x384 3 Screws, 8.2ms
# video 1/1 (121/424) /content/sekrup.mp4: 640x384 3 Screws, 9.0ms
# video 1/1 (122/424) /content/sekrup.mp4: 640x384 3 Screws, 8.8ms
# video 1/1 (123/424) /content/sekrup.mp4: 640x384 4 Screws, 9.4ms
# video 1/1 (124/424) /content/sekrup.mp4: 640x384 3 Screws, 8.9ms
# video 1/1 (125/424) /content/sekrup.mp4: 640x384 4 Screws, 9.3ms
# video 1/1 (126/424) /content/sekrup.mp4: 640x384 4 Screws, 9.5ms
# video 1/1 (127/424) /content/sekrup.mp4: 640x384 4 Screws, 9.1ms
# video 1/1 (128/424) /content/sekrup.mp4: 640x384 4 Screws, 10.0ms
# video 1/1 (129/424) /content/sekrup.mp4: 640x384 4 Screws, 9.3ms
# video 1/1 (130/424) /content/sekrup.mp4: 640x384 4 Screws, 8.9ms
# video 1/1 (131/424) /content/sekrup.mp4: 640x384 3 Screws, 8.9ms
# video 1/1 (132/424) /content/sekrup.mp4: 640x384 3 Screws, 9.9ms
# video 1/1 (133/424) /content/sekrup.mp4: 640x384 4 Screws, 9.0ms
# video 1/1 (134/424) /content/sekrup.mp4: 640x384 4 Screws, 9.0ms
# video 1/1 (135/424) /content/sekrup.mp4: 640x384 4 Screws, 9.0ms
# video 1/1 (136/424) /content/sekrup.mp4: 640x384 4 Screws, 9.0ms
# video 1/1 (137/424) /content/sekrup.mp4: 640x384 4 Screws, 8.9ms
# video 1/1 (138/424) /content/sekrup.mp4: 640x384 4 Screws, 9.0ms
# video 1/1 (139/424) /content/sekrup.mp4: 640x384 4 Screws, 8.9ms
# video 1/1 (140/424) /content/sekrup.mp4: 640x384 4 Screws, 9.0ms
# video 1/1 (141/424) /content/sekrup.mp4: 640x384 4 Screws, 8.8ms
# video 1/1 (142/424) /content/sekrup.mp4: 640x384 4 Screws, 9.5ms
# video 1/1 (143/424) /content/sekrup.mp4: 640x384 4 Screws, 13.9ms
# video 1/1 (144/424) /content/sekrup.mp4: 640x384 4 Screws, 16.5ms
# video 1/1 (145/424) /content/sekrup.mp4: 640x384 4 Screws, 15.9ms
# video 1/1 (146/424) /content/sekrup.mp4: 640x384 4 Screws, 11.1ms
# video 1/1 (147/424) /content/sekrup.mp4: 640x384 3 Screws, 7.9ms
# video 1/1 (148/424) /content/sekrup.mp4: 640x384 3 Screws, 13.2ms
# video 1/1 (149/424) /content/sekrup.mp4: 640x384 3 Screws, 13.2ms
# video 1/1 (150/424) /content/sekrup.mp4: 640x384 3 Screws, 14.6ms
# video 1/1 (151/424) /content/sekrup.mp4: 640x384 4 Screws, 8.5ms
# video 1/1 (152/424) /content/sekrup.mp4: 640x384 4 Screws, 14.1ms
# video 1/1 (153/424) /content/sekrup.mp4: 640x384 4 Screws, 8.2ms
# video 1/1 (154/424) /content/sekrup.mp4: 640x384 4 Screws, 15.2ms
# video 1/1 (155/424) /content/sekrup.mp4: 640x384 4 Screws, 7.8ms
# video 1/1 (156/424) /content/sekrup.mp4: 640x384 4 Screws, 10.7ms
# video 1/1 (157/424) /content/sekrup.mp4: 640x384 4 Screws, 7.7ms
# video 1/1 (158/424) /content/sekrup.mp4: 640x384 4 Screws, 12.7ms
# video 1/1 (159/424) /content/sekrup.mp4: 640x384 4 Screws, 12.0ms
# video 1/1 (160/424) /content/sekrup.mp4: 640x384 4 Screws, 9.9ms
# video 1/1 (161/424) /content/sekrup.mp4: 640x384 4 Screws, 17.6ms
# video 1/1 (162/424) /content/sekrup.mp4: 640x384 4 Screws, 16.5ms
# video 1/1 (163/424) /content/sekrup.mp4: 640x384 4 Screws, 10.5ms
# video 1/1 (164/424) /content/sekrup.mp4: 640x384 4 Screws, 18.0ms
# video 1/1 (165/424) /content/sekrup.mp4: 640x384 4 Screws, 18.0ms
# video 1/1 (166/424) /content/sekrup.mp4: 640x384 4 Screws, 14.8ms
# video 1/1 (167/424) /content/sekrup.mp4: 640x384 4 Screws, 15.8ms
# video 1/1 (168/424) /content/sekrup.mp4: 640x384 4 Screws, 13.4ms
# video 1/1 (169/424) /content/sekrup.mp4: 640x384 4 Screws, 15.8ms
# video 1/1 (170/424) /content/sekrup.mp4: 640x384 4 Screws, 16.6ms
# video 1/1 (171/424) /content/sekrup.mp4: 640x384 4 Screws, 19.3ms
# video 1/1 (172/424) /content/sekrup.mp4: 640x384 4 Screws, 10.6ms
# video 1/1 (173/424) /content/sekrup.mp4: 640x384 4 Screws, 15.1ms
# video 1/1 (174/424) /content/sekrup.mp4: 640x384 4 Screws, 14.0ms
# video 1/1 (175/424) /content/sekrup.mp4: 640x384 4 Screws, 7.7ms
# video 1/1 (176/424) /content/sekrup.mp4: 640x384 4 Screws, 8.0ms
# video 1/1 (177/424) /content/sekrup.mp4: 640x384 3 Screws, 12.2ms
# video 1/1 (178/424) /content/sekrup.mp4: 640x384 4 Screws, 14.4ms
# video 1/1 (179/424) /content/sekrup.mp4: 640x384 4 Screws, 13.7ms
# video 1/1 (180/424) /content/sekrup.mp4: 640x384 4 Screws, 14.5ms
# video 1/1 (181/424) /content/sekrup.mp4: 640x384 4 Screws, 7.7ms
# video 1/1 (182/424) /content/sekrup.mp4: 640x384 3 Screws, 14.3ms
# video 1/1 (183/424) /content/sekrup.mp4: 640x384 4 Screws, 7.6ms
# video 1/1 (184/424) /content/sekrup.mp4: 640x384 3 Screws, 13.7ms
# video 1/1 (185/424) /content/sekrup.mp4: 640x384 3 Screws, 7.6ms
# video 1/1 (186/424) /content/sekrup.mp4: 640x384 3 Screws, 10.4ms
# video 1/1 (187/424) /content/sekrup.mp4: 640x384 3 Screws, 19.7ms
# video 1/1 (188/424) /content/sekrup.mp4: 640x384 4 Screws, 15.8ms
# video 1/1 (189/424) /content/sekrup.mp4: 640x384 4 Screws, 9.7ms
# video 1/1 (190/424) /content/sekrup.mp4: 640x384 4 Screws, 13.9ms
# video 1/1 (191/424) /content/sekrup.mp4: 640x384 3 Screws, 11.6ms
# video 1/1 (192/424) /content/sekrup.mp4: 640x384 4 Screws, 18.3ms
# video 1/1 (193/424) /content/sekrup.mp4: 640x384 4 Screws, 15.5ms
# video 1/1 (194/424) /content/sekrup.mp4: 640x384 3 Screws, 18.2ms
# video 1/1 (195/424) /content/sekrup.mp4: 640x384 4 Screws, 19.4ms
# video 1/1 (196/424) /content/sekrup.mp4: 640x384 3 Screws, 15.6ms
# video 1/1 (197/424) /content/sekrup.mp4: 640x384 3 Screws, 19.8ms
# video 1/1 (198/424) /content/sekrup.mp4: 640x384 2 Screws, 15.4ms
# video 1/1 (199/424) /content/sekrup.mp4: 640x384 3 Screws, 18.9ms
# video 1/1 (200/424) /content/sekrup.mp4: 640x384 3 Screws, 14.9ms
# video 1/1 (201/424) /content/sekrup.mp4: 640x384 3 Screws, 8.0ms
# video 1/1 (202/424) /content/sekrup.mp4: 640x384 3 Screws, 9.9ms
# video 1/1 (203/424) /content/sekrup.mp4: 640x384 3 Screws, 11.2ms
# video 1/1 (204/424) /content/sekrup.mp4: 640x384 3 Screws, 13.6ms
# video 1/1 (205/424) /content/sekrup.mp4: 640x384 3 Screws, 15.1ms
# video 1/1 (206/424) /content/sekrup.mp4: 640x384 3 Screws, 14.6ms
# video 1/1 (207/424) /content/sekrup.mp4: 640x384 3 Screws, 15.4ms
# video 1/1 (208/424) /content/sekrup.mp4: 640x384 3 Screws, 13.2ms
# video 1/1 (209/424) /content/sekrup.mp4: 640x384 3 Screws, 16.7ms
# video 1/1 (210/424) /content/sekrup.mp4: 640x384 3 Screws, 16.8ms
# video 1/1 (211/424) /content/sekrup.mp4: 640x384 2 Screws, 11.0ms
# video 1/1 (212/424) /content/sekrup.mp4: 640x384 2 Screws, 15.0ms
# video 1/1 (213/424) /content/sekrup.mp4: 640x384 2 Screws, 8.4ms
# video 1/1 (214/424) /content/sekrup.mp4: 640x384 3 Screws, 17.1ms
# video 1/1 (215/424) /content/sekrup.mp4: 640x384 2 Screws, 15.2ms
# video 1/1 (216/424) /content/sekrup.mp4: 640x384 2 Screws, 16.2ms
# video 1/1 (217/424) /content/sekrup.mp4: 640x384 3 Screws, 14.3ms
# video 1/1 (218/424) /content/sekrup.mp4: 640x384 3 Screws, 12.0ms
# video 1/1 (219/424) /content/sekrup.mp4: 640x384 4 Screws, 14.8ms
# video 1/1 (220/424) /content/sekrup.mp4: 640x384 4 Screws, 14.8ms
# video 1/1 (221/424) /content/sekrup.mp4: 640x384 4 Screws, 19.0ms
# video 1/1 (222/424) /content/sekrup.mp4: 640x384 4 Screws, 18.7ms
# video 1/1 (223/424) /content/sekrup.mp4: 640x384 5 Screws, 20.4ms
# video 1/1 (224/424) /content/sekrup.mp4: 640x384 5 Screws, 11.9ms
# video 1/1 (225/424) /content/sekrup.mp4: 640x384 5 Screws, 10.0ms
# video 1/1 (226/424) /content/sekrup.mp4: 640x384 5 Screws, 14.9ms
# video 1/1 (227/424) /content/sekrup.mp4: 640x384 4 Screws, 20.8ms
# video 1/1 (228/424) /content/sekrup.mp4: 640x384 5 Screws, 16.9ms
# video 1/1 (229/424) /content/sekrup.mp4: 640x384 5 Screws, 14.0ms
# video 1/1 (230/424) /content/sekrup.mp4: 640x384 5 Screws, 14.6ms
# video 1/1 (231/424) /content/sekrup.mp4: 640x384 5 Screws, 14.8ms
# video 1/1 (232/424) /content/sekrup.mp4: 640x384 5 Screws, 16.1ms
# video 1/1 (233/424) /content/sekrup.mp4: 640x384 5 Screws, 10.6ms
# video 1/1 (234/424) /content/sekrup.mp4: 640x384 5 Screws, 15.6ms
# video 1/1 (235/424) /content/sekrup.mp4: 640x384 5 Screws, 10.5ms
# video 1/1 (236/424) /content/sekrup.mp4: 640x384 5 Screws, 14.3ms
# video 1/1 (237/424) /content/sekrup.mp4: 640x384 5 Screws, 10.1ms
# video 1/1 (238/424) /content/sekrup.mp4: 640x384 5 Screws, 22.5ms
# video 1/1 (239/424) /content/sekrup.mp4: 640x384 5 Screws, 10.2ms
# video 1/1 (240/424) /content/sekrup.mp4: 640x384 5 Screws, 18.6ms
# video 1/1 (241/424) /content/sekrup.mp4: 640x384 5 Screws, 13.2ms
# video 1/1 (242/424) /content/sekrup.mp4: 640x384 5 Screws, 15.1ms
# video 1/1 (243/424) /content/sekrup.mp4: 640x384 5 Screws, 7.9ms
# video 1/1 (244/424) /content/sekrup.mp4: 640x384 5 Screws, 8.7ms
# video 1/1 (245/424) /content/sekrup.mp4: 640x384 5 Screws, 20.2ms
# video 1/1 (246/424) /content/sekrup.mp4: 640x384 5 Screws, 17.3ms
# video 1/1 (247/424) /content/sekrup.mp4: 640x384 5 Screws, 13.2ms
# video 1/1 (248/424) /content/sekrup.mp4: 640x384 5 Screws, 17.8ms
# video 1/1 (249/424) /content/sekrup.mp4: 640x384 5 Screws, 14.6ms
# video 1/1 (250/424) /content/sekrup.mp4: 640x384 5 Screws, 7.7ms
# video 1/1 (251/424) /content/sekrup.mp4: 640x384 5 Screws, 14.9ms
# video 1/1 (252/424) /content/sekrup.mp4: 640x384 5 Screws, 14.6ms
# video 1/1 (253/424) /content/sekrup.mp4: 640x384 5 Screws, 15.6ms
# video 1/1 (254/424) /content/sekrup.mp4: 640x384 5 Screws, 14.5ms
# video 1/1 (255/424) /content/sekrup.mp4: 640x384 5 Screws, 17.8ms
# video 1/1 (256/424) /content/sekrup.mp4: 640x384 5 Screws, 17.9ms
# video 1/1 (257/424) /content/sekrup.mp4: 640x384 5 Screws, 15.6ms
# video 1/1 (258/424) /content/sekrup.mp4: 640x384 5 Screws, 15.1ms
# video 1/1 (259/424) /content/sekrup.mp4: 640x384 5 Screws, 13.1ms
# video 1/1 (260/424) /content/sekrup.mp4: 640x384 5 Screws, 14.0ms
# video 1/1 (261/424) /content/sekrup.mp4: 640x384 5 Screws, 11.5ms
# video 1/1 (262/424) /content/sekrup.mp4: 640x384 5 Screws, 10.1ms
# video 1/1 (263/424) /content/sekrup.mp4: 640x384 5 Screws, 7.7ms
# video 1/1 (264/424) /content/sekrup.mp4: 640x384 5 Screws, 11.9ms
# video 1/1 (265/424) /content/sekrup.mp4: 640x384 5 Screws, 8.3ms
# video 1/1 (266/424) /content/sekrup.mp4: 640x384 5 Screws, 7.6ms
# video 1/1 (267/424) /content/sekrup.mp4: 640x384 5 Screws, 10.4ms
# video 1/1 (268/424) /content/sekrup.mp4: 640x384 5 Screws, 16.8ms
# video 1/1 (269/424) /content/sekrup.mp4: 640x384 5 Screws, 7.6ms
# video 1/1 (270/424) /content/sekrup.mp4: 640x384 5 Screws, 20.4ms
# video 1/1 (271/424) /content/sekrup.mp4: 640x384 5 Screws, 16.7ms
# video 1/1 (272/424) /content/sekrup.mp4: 640x384 5 Screws, 18.4ms
# video 1/1 (273/424) /content/sekrup.mp4: 640x384 5 Screws, 14.6ms
# video 1/1 (274/424) /content/sekrup.mp4: 640x384 5 Screws, 14.8ms
# video 1/1 (275/424) /content/sekrup.mp4: 640x384 5 Screws, 20.2ms
# video 1/1 (276/424) /content/sekrup.mp4: 640x384 5 Screws, 8.5ms
# video 1/1 (277/424) /content/sekrup.mp4: 640x384 5 Screws, 9.8ms
# video 1/1 (278/424) /content/sekrup.mp4: 640x384 6 Screws, 9.6ms
# video 1/1 (279/424) /content/sekrup.mp4: 640x384 4 Screws, 12.9ms
# video 1/1 (280/424) /content/sekrup.mp4: 640x384 5 Screws, 12.8ms
# video 1/1 (281/424) /content/sekrup.mp4: 640x384 5 Screws, 12.8ms
# video 1/1 (282/424) /content/sekrup.mp4: 640x384 4 Screws, 17.5ms
# video 1/1 (283/424) /content/sekrup.mp4: 640x384 4 Screws, 20.3ms
# video 1/1 (284/424) /content/sekrup.mp4: 640x384 4 Screws, 14.8ms
# video 1/1 (285/424) /content/sekrup.mp4: 640x384 4 Screws, 8.1ms
# video 1/1 (286/424) /content/sekrup.mp4: 640x384 4 Screws, 14.9ms
# video 1/1 (287/424) /content/sekrup.mp4: 640x384 6 Screws, 10.3ms
# video 1/1 (288/424) /content/sekrup.mp4: 640x384 4 Screws, 17.6ms
# video 1/1 (289/424) /content/sekrup.mp4: 640x384 4 Screws, 8.9ms
# video 1/1 (290/424) /content/sekrup.mp4: 640x384 3 Screws, 13.0ms
# video 1/1 (291/424) /content/sekrup.mp4: 640x384 5 Screws, 8.5ms
# video 1/1 (292/424) /content/sekrup.mp4: 640x384 5 Screws, 10.7ms
# video 1/1 (293/424) /content/sekrup.mp4: 640x384 3 Screws, 9.4ms
# video 1/1 (294/424) /content/sekrup.mp4: 640x384 4 Screws, 10.9ms
# video 1/1 (295/424) /content/sekrup.mp4: 640x384 5 Screws, 11.0ms
# video 1/1 (296/424) /content/sekrup.mp4: 640x384 4 Screws, 9.1ms
# video 1/1 (297/424) /content/sekrup.mp4: 640x384 3 Screws, 9.2ms
# video 1/1 (298/424) /content/sekrup.mp4: 640x384 4 Screws, 9.3ms
# video 1/1 (299/424) /content/sekrup.mp4: 640x384 4 Screws, 11.4ms
# video 1/1 (300/424) /content/sekrup.mp4: 640x384 4 Screws, 8.1ms
# video 1/1 (301/424) /content/sekrup.mp4: 640x384 4 Screws, 9.2ms
# video 1/1 (302/424) /content/sekrup.mp4: 640x384 5 Screws, 9.5ms
# video 1/1 (303/424) /content/sekrup.mp4: 640x384 6 Screws, 9.6ms
# video 1/1 (304/424) /content/sekrup.mp4: 640x384 4 Screws, 9.1ms
# video 1/1 (305/424) /content/sekrup.mp4: 640x384 5 Screws, 9.6ms
# video 1/1 (306/424) /content/sekrup.mp4: 640x384 5 Screws, 9.2ms
# video 1/1 (307/424) /content/sekrup.mp4: 640x384 4 Screws, 9.3ms
# video 1/1 (308/424) /content/sekrup.mp4: 640x384 4 Screws, 9.8ms
# video 1/1 (309/424) /content/sekrup.mp4: 640x384 5 Screws, 9.1ms
# video 1/1 (310/424) /content/sekrup.mp4: 640x384 5 Screws, 9.5ms
# video 1/1 (311/424) /content/sekrup.mp4: 640x384 4 Screws, 8.7ms
# video 1/1 (312/424) /content/sekrup.mp4: 640x384 4 Screws, 9.0ms
# video 1/1 (313/424) /content/sekrup.mp4: 640x384 5 Screws, 9.1ms
# video 1/1 (314/424) /content/sekrup.mp4: 640x384 4 Screws, 8.9ms
# video 1/1 (315/424) /content/sekrup.mp4: 640x384 4 Screws, 9.1ms
# video 1/1 (316/424) /content/sekrup.mp4: 640x384 4 Screws, 9.1ms
# video 1/1 (317/424) /content/sekrup.mp4: 640x384 4 Screws, 9.0ms
# video 1/1 (318/424) /content/sekrup.mp4: 640x384 4 Screws, 10.2ms
# video 1/1 (319/424) /content/sekrup.mp4: 640x384 4 Screws, 9.2ms
# video 1/1 (320/424) /content/sekrup.mp4: 640x384 4 Screws, 9.4ms
# video 1/1 (321/424) /content/sekrup.mp4: 640x384 4 Screws, 9.0ms
# video 1/1 (322/424) /content/sekrup.mp4: 640x384 4 Screws, 9.0ms
# video 1/1 (323/424) /content/sekrup.mp4: 640x384 4 Screws, 9.1ms
# video 1/1 (324/424) /content/sekrup.mp4: 640x384 5 Screws, 9.1ms
# video 1/1 (325/424) /content/sekrup.mp4: 640x384 4 Screws, 9.4ms
# video 1/1 (326/424) /content/sekrup.mp4: 640x384 4 Screws, 10.1ms
# video 1/1 (327/424) /content/sekrup.mp4: 640x384 4 Screws, 9.6ms
# video 1/1 (328/424) /content/sekrup.mp4: 640x384 4 Screws, 9.5ms
# video 1/1 (329/424) /content/sekrup.mp4: 640x384 4 Screws, 9.9ms
# video 1/1 (330/424) /content/sekrup.mp4: 640x384 4 Screws, 9.1ms
# video 1/1 (331/424) /content/sekrup.mp4: 640x384 4 Screws, 9.1ms
# video 1/1 (332/424) /content/sekrup.mp4: 640x384 5 Screws, 9.5ms
# video 1/1 (333/424) /content/sekrup.mp4: 640x384 5 Screws, 11.0ms
# video 1/1 (334/424) /content/sekrup.mp4: 640x384 5 Screws, 8.8ms
# video 1/1 (335/424) /content/sekrup.mp4: 640x384 6 Screws, 9.5ms
# video 1/1 (336/424) /content/sekrup.mp4: 640x384 5 Screws, 9.0ms
# video 1/1 (337/424) /content/sekrup.mp4: 640x384 5 Screws, 10.2ms
# video 1/1 (338/424) /content/sekrup.mp4: 640x384 5 Screws, 9.3ms
# video 1/1 (339/424) /content/sekrup.mp4: 640x384 5 Screws, 9.2ms
# video 1/1 (340/424) /content/sekrup.mp4: 640x384 5 Screws, 9.7ms
# video 1/1 (341/424) /content/sekrup.mp4: 640x384 5 Screws, 11.1ms
# video 1/1 (342/424) /content/sekrup.mp4: 640x384 5 Screws, 9.3ms
# video 1/1 (343/424) /content/sekrup.mp4: 640x384 6 Screws, 9.3ms
# video 1/1 (344/424) /content/sekrup.mp4: 640x384 6 Screws, 9.1ms
# video 1/1 (345/424) /content/sekrup.mp4: 640x384 6 Screws, 9.9ms
# video 1/1 (346/424) /content/sekrup.mp4: 640x384 6 Screws, 9.4ms
# video 1/1 (347/424) /content/sekrup.mp4: 640x384 5 Screws, 9.4ms
# video 1/1 (348/424) /content/sekrup.mp4: 640x384 6 Screws, 9.4ms
# video 1/1 (349/424) /content/sekrup.mp4: 640x384 6 Screws, 9.7ms
# video 1/1 (350/424) /content/sekrup.mp4: 640x384 6 Screws, 9.6ms
# video 1/1 (351/424) /content/sekrup.mp4: 640x384 3 Screws, 9.2ms
# video 1/1 (352/424) /content/sekrup.mp4: 640x384 6 Screws, 9.4ms
# video 1/1 (353/424) /content/sekrup.mp4: 640x384 6 Screws, 9.0ms
# video 1/1 (354/424) /content/sekrup.mp4: 640x384 5 Screws, 9.3ms
# video 1/1 (355/424) /content/sekrup.mp4: 640x384 5 Screws, 9.2ms
# video 1/1 (356/424) /content/sekrup.mp4: 640x384 4 Screws, 10.6ms
# video 1/1 (357/424) /content/sekrup.mp4: 640x384 4 Screws, 18.7ms
# video 1/1 (358/424) /content/sekrup.mp4: 640x384 4 Screws, 11.4ms
# video 1/1 (359/424) /content/sekrup.mp4: 640x384 5 Screws, 10.3ms
# video 1/1 (360/424) /content/sekrup.mp4: 640x384 5 Screws, 9.6ms
# video 1/1 (361/424) /content/sekrup.mp4: 640x384 6 Screws, 10.6ms
# video 1/1 (362/424) /content/sekrup.mp4: 640x384 6 Screws, 9.8ms
# video 1/1 (363/424) /content/sekrup.mp4: 640x384 5 Screws, 9.6ms
# video 1/1 (364/424) /content/sekrup.mp4: 640x384 5 Screws, 9.1ms
# video 1/1 (365/424) /content/sekrup.mp4: 640x384 5 Screws, 9.3ms
# video 1/1 (366/424) /content/sekrup.mp4: 640x384 3 Screws, 10.0ms
# video 1/1 (367/424) /content/sekrup.mp4: 640x384 6 Screws, 14.4ms
# video 1/1 (368/424) /content/sekrup.mp4: 640x384 6 Screws, 9.8ms
# video 1/1 (369/424) /content/sekrup.mp4: 640x384 5 Screws, 10.5ms
# video 1/1 (370/424) /content/sekrup.mp4: 640x384 5 Screws, 10.1ms
# video 1/1 (371/424) /content/sekrup.mp4: 640x384 5 Screws, 10.8ms
# video 1/1 (372/424) /content/sekrup.mp4: 640x384 6 Screws, 9.5ms
# video 1/1 (373/424) /content/sekrup.mp4: 640x384 5 Screws, 9.3ms
# video 1/1 (374/424) /content/sekrup.mp4: 640x384 5 Screws, 9.8ms
# video 1/1 (375/424) /content/sekrup.mp4: 640x384 6 Screws, 9.5ms
# video 1/1 (376/424) /content/sekrup.mp4: 640x384 5 Screws, 9.7ms
# video 1/1 (377/424) /content/sekrup.mp4: 640x384 5 Screws, 9.3ms
# video 1/1 (378/424) /content/sekrup.mp4: 640x384 5 Screws, 12.2ms
# video 1/1 (379/424) /content/sekrup.mp4: 640x384 4 Screws, 9.4ms
# video 1/1 (380/424) /content/sekrup.mp4: 640x384 5 Screws, 9.3ms
# video 1/1 (381/424) /content/sekrup.mp4: 640x384 5 Screws, 9.2ms
# video 1/1 (382/424) /content/sekrup.mp4: 640x384 5 Screws, 9.5ms
# video 1/1 (383/424) /content/sekrup.mp4: 640x384 5 Screws, 9.5ms
# video 1/1 (384/424) /content/sekrup.mp4: 640x384 5 Screws, 9.5ms
# video 1/1 (385/424) /content/sekrup.mp4: 640x384 6 Screws, 9.2ms
# video 1/1 (386/424) /content/sekrup.mp4: 640x384 5 Screws, 8.9ms
# video 1/1 (387/424) /content/sekrup.mp4: 640x384 6 Screws, 9.2ms
# video 1/1 (388/424) /content/sekrup.mp4: 640x384 6 Screws, 9.2ms
# video 1/1 (389/424) /content/sekrup.mp4: 640x384 6 Screws, 9.2ms
# video 1/1 (390/424) /content/sekrup.mp4: 640x384 6 Screws, 8.4ms
# video 1/1 (391/424) /content/sekrup.mp4: 640x384 6 Screws, 9.4ms
# video 1/1 (392/424) /content/sekrup.mp4: 640x384 6 Screws, 9.6ms
# video 1/1 (393/424) /content/sekrup.mp4: 640x384 6 Screws, 10.0ms
# video 1/1 (394/424) /content/sekrup.mp4: 640x384 6 Screws, 12.0ms
# video 1/1 (395/424) /content/sekrup.mp4: 640x384 6 Screws, 9.7ms
# video 1/1 (396/424) /content/sekrup.mp4: 640x384 6 Screws, 9.5ms
# video 1/1 (397/424) /content/sekrup.mp4: 640x384 6 Screws, 9.3ms
# video 1/1 (398/424) /content/sekrup.mp4: 640x384 6 Screws, 9.1ms
# video 1/1 (399/424) /content/sekrup.mp4: 640x384 6 Screws, 9.2ms
# video 1/1 (400/424) /content/sekrup.mp4: 640x384 6 Screws, 10.5ms
# video 1/1 (401/424) /content/sekrup.mp4: 640x384 6 Screws, 9.6ms
# video 1/1 (402/424) /content/sekrup.mp4: 640x384 6 Screws, 8.9ms
# video 1/1 (403/424) /content/sekrup.mp4: 640x384 6 Screws, 9.1ms
# video 1/1 (404/424) /content/sekrup.mp4: 640x384 6 Screws, 9.8ms
# video 1/1 (405/424) /content/sekrup.mp4: 640x384 6 Screws, 9.2ms
# video 1/1 (406/424) /content/sekrup.mp4: 640x384 5 Screws, 9.5ms
# video 1/1 (407/424) /content/sekrup.mp4: 640x384 5 Screws, 11.0ms
# video 1/1 (408/424) /content/sekrup.mp4: 640x384 5 Screws, 12.4ms
# video 1/1 (409/424) /content/sekrup.mp4: 640x384 6 Screws, 8.8ms
# video 1/1 (410/424) /content/sekrup.mp4: 640x384 6 Screws, 9.2ms
# video 1/1 (411/424) /content/sekrup.mp4: 640x384 6 Screws, 9.1ms
# video 1/1 (412/424) /content/sekrup.mp4: 640x384 6 Screws, 9.2ms
# video 1/1 (413/424) /content/sekrup.mp4: 640x384 6 Screws, 9.3ms
# video 1/1 (414/424) /content/sekrup.mp4: 640x384 6 Screws, 9.4ms
# video 1/1 (415/424) /content/sekrup.mp4: 640x384 6 Screws, 10.1ms
# video 1/1 (416/424) /content/sekrup.mp4: 640x384 6 Screws, 10.1ms
# video 1/1 (417/424) /content/sekrup.mp4: 640x384 6 Screws, 9.4ms
# video 1/1 (418/424) /content/sekrup.mp4: 640x384 6 Screws, 9.5ms
# video 1/1 (419/424) /content/sekrup.mp4: 640x384 6 Screws, 9.2ms
# video 1/1 (420/424) /content/sekrup.mp4: 640x384 6 Screws, 8.2ms
# video 1/1 (421/424) /content/sekrup.mp4: 640x384 6 Screws, 8.7ms
# video 1/1 (422/424) /content/sekrup.mp4: 640x384 5 Screws, 8.9ms
# video 1/1 (423/424) /content/sekrup.mp4: 640x384 6 Screws, 8.9ms
# video 1/1 (424/424) /content/sekrup.mp4: 640x384 6 Screws, 7.5ms
# Speed: 0.5ms pre-process, 11.1ms inference, 1.7ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp15

# %%
# !python /content/yolov5/export.py --weights runs/train/exp2/weights/best.pt --include tfjs
# Out:
# export: data=data/coco128.yaml, weights=['runs/train/exp2/weights/best.pt'], imgsz=[640, 640], batch_size=1, device=cpu, half=False, inplace=False, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=17, verbose=False, workspace=4, nms=False, agnostic_nms=False, topk_per_class=100, topk_all=100, iou_thres=0.45, conf_thres=0.25, include=['tfjs']
# YOLOv5 🚀 v7.0-247-g3f02fde Python-3.10.12 torch-2.1.0+cu118 CPU
#
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
#
# PyTorch: starting from runs/train/exp2/weights/best.pt with output shape (1, 25200, 6) (13.8 MB)
# 2023-12-08 12:13:08.719585: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-08 12:13:08.719635: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-08 12:13:08.720925: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
#
# TensorFlow SavedModel: starting export with tensorflow 2.15.0...
#
#                  from  n    params  module                                  arguments
# 2023-12-08 12:13:10.475435: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:274] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
#   0                -1  1      3520  models.common.Conv                      [3, 32, 6, 2, 2]
#   1                -1  1     18560  models.common.Conv                      [32, 64, 3, 2]
#   2                -1  1     18816  models.common.C3                        [64, 64, 1]
#   3                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   4                -1  1    115712  models.common.C3                        [128, 128, 2]
#   5                -1  1    295424  models.common.Conv                      [128, 256, 3, 2]
#   6                -1  1    625152  models.common.C3                        [256, 256, 3]
#   7                -1  1   1180672  models.common.Conv                      [256, 512, 3, 2]
#   8                -1  1   1182720  models.common.C3                        [512, 512, 1]
#   9                -1  1    656896  models.common.SPPF                      [512, 512, 5]
#  10                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  1    361984  models.common.C3                        [512, 256, 1, False]
#  14                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  1     90880  models.common.C3                        [256, 128, 1, False]
#  18                -1  1    147712  models.common.Conv                      [128, 128, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  1    296448  models.common.C3                        [256, 256, 1, False]
#  21                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  1   1182720  models.common.C3                        [512, 512, 1, False]
#  24      [17, 20, 23]  1     16182  models.yolo.Detect                      [1, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [128, 256, 512], [640, 640]]
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(1, 640, 640, 3)]           0         []
#
#  tf_conv (TFConv)            (1, 320, 320, 32)            3488      ['input_1[0][0]']
#
#  tf_conv_1 (TFConv)          (1, 160, 160, 64)            18496     ['tf_conv[0][0]']
#
#  tfc3 (TFC3)                 (1, 160, 160, 64)            18624     ['tf_conv_1[0][0]']
#
#  tf_conv_7 (TFConv)          (1, 80, 80, 128)             73856     ['tfc3[0][0]']
#
#  tfc3_1 (TFC3)               (1, 80, 80, 128)             115200    ['tf_conv_7[0][0]']
#
#  tf_conv_15 (TFConv)         (1, 40, 40, 256)             295168    ['tfc3_1[0][0]']
#
#  tfc3_2 (TFC3)               (1, 40, 40, 256)             623872    ['tf_conv_15[0][0]']
#
#  tf_conv_25 (TFConv)         (1, 20, 20, 512)             1180160   ['tfc3_2[0][0]']
#
#  tfc3_3 (TFC3)               (1, 20, 20, 512)             1181184   ['tf_conv_25[0][0]']
#
#  tfsppf (TFSPPF)             (1, 20, 20, 512)             656128    ['tfc3_3[0][0]']
#
#  tf_conv_33 (TFConv)         (1, 20, 20, 256)             131328    ['tfsppf[0][0]']
#
#  tf_upsample (TFUpsample)    (1, 40, 40, 256)             0         ['tf_conv_33[0][0]']
#
#  tf_concat (TFConcat)        (1, 40, 40, 512)             0         ['tf_upsample[0][0]',
#                                                                      'tfc3_2[0][0]']
#
#  tfc3_4 (TFC3)               (1, 40, 40, 256)             361216    ['tf_concat[0][0]']
#
#  tf_conv_39 (TFConv)         (1, 40, 40, 128)             32896     ['tfc3_4[0][0]']
#
#  tf_upsample_1 (TFUpsample)  (1, 80, 80, 128)             0         ['tf_conv_39[0][0]']
#
#  tf_concat_1 (TFConcat)      (1, 80, 80, 256)             0         ['tf_upsample_1[0][0]',
#                                                                      'tfc3_1[0][0]']
#
#  tfc3_5 (TFC3)               (1, 80, 80, 128)             90496     ['tf_concat_1[0][0]']
#
#  tf_conv_45 (TFConv)         (1, 40, 40, 128)             147584    ['tfc3_5[0][0]']
#
#  tf_concat_2 (TFConcat)      (1, 40, 40, 256)             0         ['tf_conv_45[0][0]',
#                                                                      'tf_conv_39[0][0]']
#
#  tfc3_6 (TFC3)               (1, 40, 40, 256)             295680    ['tf_concat_2[0][0]']
#
#  tf_conv_51 (TFConv)         (1, 20, 20, 256)             590080    ['tfc3_6[0][0]']
#
#  tf_concat_3 (TFConcat)      (1, 20, 20, 512)             0         ['tf_conv_51[0][0]',
#                                                                      'tf_conv_33[0][0]']
#
#  tfc3_7 (TFC3)               (1, 20, 20, 512)             1181184   ['tf_concat_3[0][0]']
#
#  tf_detect (TFDetect)        ((1, 25200, 6),              16182     ['tfc3_5[0][0]',
#                              )                                       'tfc3_6[0][0]',
#                                                                      'tfc3_7[0][0]']
#
#  tf.__operators__.getitem (  (1, 25200, 4)                0         ['tf_detect[0][0]']
#  SlicingOpLambda)
#
#  tf.split (TFOpLambda)       [(1, 25200, 1),              0         ['tf.__operators__.getitem[0][
#                               (1, 25200, 1),                        0]']
#                               (1, 25200, 1),
#                               (1, 25200, 1)]
#
#  tf.math.truediv (TFOpLambd  (1, 25200, 1)                0         ['tf.split[0][2]']
#  a)
#
#  tf.math.truediv_1 (TFOpLam  (1, 25200, 1)                0         ['tf.split[0][3]']
#  bda)
#
#  tf.math.truediv_2 (TFOpLam  (1, 25200, 1)                0         ['tf.split[0][2]']
#  bda)
#
#  tf.math.truediv_3 (TFOpLam  (1, 25200, 1)                0         ['tf.split[0][3]']
#  bda)
#
#  tf.math.subtract (TFOpLamb  (1, 25200, 1)                0         ['tf.split[0][0]',
#  da)                                                                 'tf.math.truediv[0][0]']
#
#  tf.math.subtract_1 (TFOpLa  (1, 25200, 1)                0         ['tf.split[0][1]',
#  mbda)                                                               'tf.math.truediv_1[0][0]']
#
#  tf.__operators__.add (TFOp  (1, 25200, 1)                0         ['tf.split[0][0]',
#  Lambda)                                                             'tf.math.truediv_2[0][0]']
#
#  tf.__operators__.add_1 (TF  (1, 25200, 1)                0         ['tf.split[0][1]',
#  OpLambda)                                                           'tf.math.truediv_3[0][0]']
#
#  tf.__operators__.getitem_2  (1, 25200, 1)                0         ['tf_detect[0][0]']
#   (SlicingOpLambda)
#
#  tf.__operators__.getitem_1  (1, 25200, 1)                0         ['tf_detect[0][0]']
#   (SlicingOpLambda)
#
#  tf.concat (TFOpLambda)      (1, 25200, 4)                0         ['tf.math.subtract[0][0]',
#                                                                      'tf.math.subtract_1[0][0]',
#                                                                      'tf.__operators__.add[0][0]',
#                                                                      'tf.__operators__.add_1[0][0]
#                                                                     ']
#
#  tf.math.multiply (TFOpLamb  (1, 25200, 1)                0         ['tf.__operators__.getitem_1[0
#  da)                                                                ][0]',
#                                                                      'tf.__operators__.getitem_2[0
#                                                                     ][0]']
#
#  agnostic_nms_1 (AgnosticNM  ((1, None, 4),               0         ['tf.concat[0][0]',
#  S)                           (1, None),                             'tf.__operators__.getitem_2[0
#                               (1, None),                            ][0]',
#                               (1,))                                  'tf.math.multiply[0][0]']
#
# ==================================================================================================
# Total params: 7012822 (26.75 MB)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 7012822 (26.75 MB)
# __________________________________________________________________________________________________
# TensorFlow SavedModel: export success ✅ 10.2s, saved as runs/train/exp2/weights/best_saved_model (27.1 MB)
#
# TensorFlow GraphDef: starting export with tensorflow 2.15.0...
# TensorFlow GraphDef: export success ✅ 2.8s, saved as runs/train/exp2/weights/best.pb (27.0 MB)
#
# TensorFlow.js: starting export with tensorflowjs 4.14.0...
# 2023-12-08 12:13:22.042860: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-08 12:13:22.042910: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-08 12:13:22.044026: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# TensorFlow.js: export success ✅ 5.1s, saved as runs/train/exp2/weights/best_web_model (27.0 MB)
#
# Export complete (19.1s)
# Results saved to /content/yolov5/runs/train/exp2/weights
# Detect:          python detect.py --weights runs/train/exp2/weights/best_web_model
# Validate:        python val.py --weights runs/train/exp2/weights/best_web_model
# PyTorch Hub:     model = torch.hub.load('ultralytics/yolov5', 'custom', 'runs/train/exp2/weights/best_web_model')
# Visualize:       https://netron.app

# %% [markdown]
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <img align="left" src="https://user-images.githubusercontent.com/26833433/127574988-6a558aa1-d268-44b9-bf6b-62d4c605cc72.jpg" width="600">

# %% [markdown]
# # 2. Validate
# Validate a model's accuracy on the [COCO](https://cocodataset.org/#home) dataset's `val` or `test` splits. Models are downloaded automatically from the [latest YOLOv5 release](https://github.com/ultralytics/yolov5/releases). To show results by class use the `--verbose` flag.

# %%
# Download COCO val
torch.hub.download_url_to_file('https://ultralytics.com/assets/coco2017val.zip', 'tmp.zip')  # download (780M - 5000 images)
# !unzip -q tmp.zip -d ../datasets && rm tmp.zip  # unzip
# Out:
# 100%|██████████| 780M/780M [00:02<00:00, 283MB/s]

# %%
# Validate YOLOv5s on COCO val
# !python val.py --weights yolov5s.pt --data coco.yaml --img 640 --half
# Out:
# val: data=/content/yolov5/data/coco.yaml, weights=['yolov5s.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.6, max_det=300, task=val, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=True, project=runs/val, name=exp, exist_ok=False, half=True, dnn=False
# YOLOv5 🚀 v7.0-247-g3f02fde Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients, 16.4 GFLOPs
# val: Scanning /content/datasets/coco/val2017... 4952 images, 48 backgrounds, 0 corrupt: 100% 5000/5000 [00:03<00:00, 1484.87it/s]
# val: New cache created: /content/datasets/coco/val2017.cache
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 157/157 [01:17<00:00,  2.04it/s]
#                    all       5000      36335      0.671      0.519      0.566      0.371
# Speed: 0.1ms pre-process, 3.3ms inference, 2.1ms NMS per image at shape (32, 3, 640, 640)
#
# Evaluating pycocotools mAP... saving runs/val/exp/yolov5s_predictions.json...
# loading annotations into memory...
# Done (t=0.49s)
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=6.88s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# Traceback (most recent call last):
#   File "/content/yolov5/val.py", line 411, in <module>
#     main(opt)
#   File "/content/yolov5/val.py", line 382, in main
#     run(**vars(opt))
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/_contextlib.py", line 115, in decorate_context
#     return func(*args, **kwargs)
#   File "/content/yolov5/val.py", line 324, in run
#     eval.evaluate()
#   File "/usr/local/lib/python3.10/dist-packages/pycocotools/cocoeval.py", line 154, in evaluate
#     self.evalImgs = [evaluateImg(imgId, catId, areaRng, maxDet)
#   File "/usr/local/lib/python3.10/dist-packages/pycocotools/cocoeval.py", line 154, in <listcomp>
#     self.evalImgs = [evaluateImg(imgId, catId, areaRng, maxDet)
#   File "/usr/local/lib/python3.10/dist-packages/pycocotools/cocoeval.py", line 276, in evaluateImg
#     iou = min([t,1-1e-10])
# KeyboardInterrupt

# %% [markdown]
# # 3. Train
#
# <p align=""><a href="https://bit.ly/ultralytics_hub"><img width="1000" src="https://github.com/ultralytics/assets/raw/main/im/integrations-loop.png"/></a></p>
# Close the active learning loop by sampling images from your inference conditions with the `roboflow` pip package
# <br><br>
#
# Train a YOLOv5s model on the [COCO128](https://www.kaggle.com/ultralytics/coco128) dataset with `--data coco128.yaml`, starting from pretrained `--weights yolov5s.pt`, or from randomly initialized `--weights '' --cfg yolov5s.yaml`.
#
# - **Pretrained [Models](https://github.com/ultralytics/yolov5/tree/master/models)** are downloaded
# automatically from the [latest YOLOv5 release](https://github.com/ultralytics/yolov5/releases)
# - **[Datasets](https://github.com/ultralytics/yolov5/tree/master/data)** available for autodownload include: [COCO](https://github.com/ultralytics/yolov5/blob/master/data/coco.yaml), [COCO128](https://github.com/ultralytics/yolov5/blob/master/data/coco128.yaml), [VOC](https://github.com/ultralytics/yolov5/blob/master/data/VOC.yaml), [Argoverse](https://github.com/ultralytics/yolov5/blob/master/data/Argoverse.yaml), [VisDrone](https://github.com/ultralytics/yolov5/blob/master/data/VisDrone.yaml), [GlobalWheat](https://github.com/ultralytics/yolov5/blob/master/data/GlobalWheat2020.yaml), [xView](https://github.com/ultralytics/yolov5/blob/master/data/xView.yaml), [Objects365](https://github.com/ultralytics/yolov5/blob/master/data/Objects365.yaml), [SKU-110K](https://github.com/ultralytics/yolov5/blob/master/data/SKU-110K.yaml).
# - **Training Results** are saved to `runs/train/` with incrementing run directories, i.e. `runs/train/exp2`, `runs/train/exp3` etc.
# <br>
#
# A **Mosaic Dataloader** is used for training which combines 4 images into 1 mosaic.
#
# ## Label a dataset on Roboflow (optional)
#
# [Roboflow](https://roboflow.com/?ref=ultralytics) enables you to easily **organize, label, and prepare** a high quality dataset with your own custom data. Roboflow also makes it easy to establish an active learning pipeline, collaborate with your team on dataset improvement, and integrate directly into your model building workflow with the `roboflow` pip package.

# %%
#@title Select YOLOv5 🚀 logger {run: 'auto'}
logger = 'Comet' #@param ['Comet', 'ClearML', 'TensorBoard']

if logger == 'Comet':
  # %pip install -q comet_ml
  import comet_ml; comet_ml.init()
elif logger == 'ClearML':
  # %pip install -q clearml
  import clearml; clearml.browser_login()
elif logger == 'TensorBoard':
  # %load_ext tensorboard
  # %tensorboard --logdir runs/train

# %%
# Train YOLOv5s on COCO128 for 3 epochs
# !python train.py --img 640 --batch 16 --epochs 10 --data screw-data.yaml --weights yolov5s.pt --cache
# Out:
# 2023-12-08 10:43:02.439867: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-08 10:43:02.439923: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-08 10:43:02.439961: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# train: weights=yolov5s.pt, cfg=, data=screw-data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=10, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-247-g3f02fde Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# hyperparameters: lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, cls_pw=1.0, obj=1.0, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0
# TensorBoard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# COMET WARNING: Comet credentials have not been set. Comet will default to offline logging. Please set your credentials to enable online logging.
# COMET INFO: Using '/content/yolov5/.cometml-runs' path as offline directory. Pass 'offline_directory' parameter into constructor or set the 'COMET_OFFLINE_DIRECTORY' environment variable to manually choose where to store offline experiment archives.
# Overriding model.yaml nc=80 with nc=1
#
#                  from  n    params  module                                  arguments
#   0                -1  1      3520  models.common.Conv                      [3, 32, 6, 2, 2]
#   1                -1  1     18560  models.common.Conv                      [32, 64, 3, 2]
#   2                -1  1     18816  models.common.C3                        [64, 64, 1]
#   3                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   4                -1  2    115712  models.common.C3                        [128, 128, 2]
#   5                -1  1    295424  models.common.Conv                      [128, 256, 3, 2]
#   6                -1  3    625152  models.common.C3                        [256, 256, 3]
#   7                -1  1   1180672  models.common.Conv                      [256, 512, 3, 2]
#   8                -1  1   1182720  models.common.C3                        [512, 512, 1]
#   9                -1  1    656896  models.common.SPPF                      [512, 512, 5]
#  10                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  1    361984  models.common.C3                        [512, 256, 1, False]
#  14                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  1     90880  models.common.C3                        [256, 128, 1, False]
#  18                -1  1    147712  models.common.Conv                      [128, 128, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  1    296448  models.common.C3                        [256, 256, 1, False]
#  21                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  1   1182720  models.common.C3                        [512, 512, 1, False]
#  24      [17, 20, 23]  1     16182  models.yolo.Detect                      [1, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [128, 256, 512]]
# Model summary: 214 layers, 7022326 parameters, 7022326 gradients, 15.9 GFLOPs
#
# Transferred 343/349 items from yolov5s.pt
# AMP: checks passed ✅
# optimizer: SGD(lr=0.01) with parameter groups 57 weight(decay=0.0), 60 weight(decay=0.0005), 60 bias
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# train: Scanning /content/Screw.v4-dataset/train/labels.cache... 2904 images, 4 backgrounds, 0 corrupt: 100%|██████████| 2904/2904 [00:00<?, ?it/s]
# train: WARNING ⚠️ /content/Screw.v4-dataset/train/images/325_jpg.rf.686907d6d116480195d3963392ccb0e4.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /content/Screw.v4-dataset/train/images/WIN_20220908_19_32_25_Pro-2-_jpg.rf.bb1d95ec09fee7ccd981c4d1e65b1079.jpg: 1 duplicate labels removed
# train: Caching images (3.3GB ram): 100%|██████████| 2904/2904 [00:13<00:00, 209.31it/s]
# val: Scanning /content/Screw.v4-dataset/valid/labels.cache... 308 images, 0 backgrounds, 0 corrupt: 100%|██████████| 308/308 [00:00<?, ?it/s]
# val: Caching images (0.4GB ram): 100%|██████████| 308/308 [00:02<00:00, 146.47it/s]
#
# AutoAnchor: 4.38 anchors/target, 0.991 Best Possible Recall (BPR). Current anchors are a good fit to dataset ✅
# Plotting labels to runs/train/exp2/labels.jpg...
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to runs/train/exp2
# Starting training for 10 epochs...
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#         0/9      3.46G    0.08086     0.0559          0         76        640: 100%|██████████| 182/182 [01:00<00:00,  2.98it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 10/10 [00:08<00:00,  1.17it/s]
#                    all        308        787      0.698      0.712      0.748      0.353
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#         1/9      4.27G     0.0521    0.04359          0         45        640: 100%|██████████| 182/182 [00:58<00:00,  3.09it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 10/10 [00:03<00:00,  2.55it/s]
#                    all        308        787      0.845      0.849      0.898      0.479
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#         2/9      4.27G     0.0447    0.04035          0         78        640: 100%|██████████| 182/182 [00:55<00:00,  3.25it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 10/10 [00:04<00:00,  2.44it/s]
#                    all        308        787      0.644      0.872      0.834      0.515
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#         3/9      4.27G    0.03725    0.03723          0         43        640: 100%|██████████| 182/182 [00:56<00:00,  3.25it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 10/10 [00:04<00:00,  2.44it/s]
#                    all        308        787      0.937      0.864      0.951      0.681
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#         4/9      4.27G    0.03375    0.03682          0         75        640: 100%|██████████| 182/182 [00:56<00:00,  3.24it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 10/10 [00:04<00:00,  2.40it/s]
#                    all        308        787      0.944      0.897      0.966      0.743
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#         5/9      4.27G    0.02945    0.03395          0         45        640: 100%|██████████| 182/182 [00:56<00:00,  3.24it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 10/10 [00:04<00:00,  2.39it/s]
#                    all        308        787      0.947      0.898      0.961      0.753
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#         6/9      4.27G     0.0272    0.03424          0         50        640: 100%|██████████| 182/182 [00:58<00:00,  3.13it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 10/10 [00:05<00:00,  1.87it/s]
#                    all        308        787      0.957      0.899      0.962      0.776
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#         7/9      4.27G    0.02465    0.03288          0         57        640: 100%|██████████| 182/182 [00:56<00:00,  3.22it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 10/10 [00:04<00:00,  2.14it/s]
#                    all        308        787      0.959      0.898      0.963      0.779
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#         8/9      4.27G     0.0231    0.03172          0        105        640: 100%|██████████| 182/182 [00:54<00:00,  3.36it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 10/10 [00:05<00:00,  1.89it/s]
#                    all        308        787       0.96      0.905      0.967       0.81
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#         9/9      4.27G    0.02137    0.03051          0         50        640: 100%|██████████| 182/182 [00:54<00:00,  3.35it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 10/10 [00:05<00:00,  1.91it/s]
#                    all        308        787      0.941      0.919      0.969      0.829
#
# 10 epochs completed in 0.173 hours.
# Optimizer stripped from runs/train/exp2/weights/last.pt, 14.4MB
# Optimizer stripped from runs/train/exp2/weights/best.pt, 14.4MB
#
# Validating runs/train/exp2/weights/best.pt...
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 10/10 [00:06<00:00,  1.52it/s]
#                    all        308        787      0.941      0.919      0.969      0.829
# Results saved to runs/train/exp2
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO: Comet.ml OfflineExperiment Summary
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     url                   : [OfflineExperiment will get URL after upload]
# COMET INFO:   Metrics [count] (min, max):
# COMET INFO:     loss [181]                : (0.5940176844596863, 2.8601295948028564)
# COMET INFO:     metrics/mAP_0.5 [20]      : (0.7477559538509843, 0.9687415656365405)
# COMET INFO:     metrics/mAP_0.5:0.95 [20] : (0.35317707368279605, 0.8288580206471934)
# COMET INFO:     metrics/precision [20]    : (0.6435038102752461, 0.959648575812903)
# COMET INFO:     metrics/recall [20]       : (0.7117670402295562, 0.9186785260482846)
# COMET INFO:     train/box_loss [20]       : (0.02136511355638504, 0.08085717260837555)
# COMET INFO:     train/cls_loss            : 0.0
# COMET INFO:     train/obj_loss [20]       : (0.03051348589360714, 0.055897194892168045)
# COMET INFO:     val/box_loss [20]         : (0.013017626479268074, 0.04468240216374397)
# COMET INFO:     val/cls_loss              : 0.0
# COMET INFO:     val/obj_loss [20]         : (0.00744817266240716, 0.0133125064894557)
# COMET INFO:     x/lr0 [20]                : (0.00208, 0.07016483516483517)
# COMET INFO:     x/lr1 [20]                : (0.00208, 0.008005311355311356)
# COMET INFO:     x/lr2 [20]                : (0.00208, 0.008005311355311356)
# COMET INFO:   Others:
# COMET INFO:     Name                        : exp
# COMET INFO:     comet_log_batch_metrics     : False
# COMET INFO:     comet_log_confusion_matrix  : True
# COMET INFO:     comet_log_per_class_metrics : False
# COMET INFO:     comet_max_image_uploads     : 100
# COMET INFO:     comet_mode                  : online
# COMET INFO:     comet_model_name            : yolov5
# COMET INFO:     hasNestedParams             : True
# COMET INFO:     offline_experiment          : True
# COMET INFO:   Parameters:
# COMET INFO:     anchor_t            : 4.0
# COMET INFO:     artifact_alias      : latest
# COMET INFO:     batch_size          : 16
# COMET INFO:     bbox_interval       : -1
# COMET INFO:     box                 : 0.05
# COMET INFO:     bucket              :
# COMET INFO:     cfg                 :
# COMET INFO:     cls                 : 0.006250000000000001
# COMET INFO:     cls_pw              : 1.0
# COMET INFO:     copy_paste          : 0.0
# COMET INFO:     cos_lr              : False
# COMET INFO:     degrees             : 0.0
# COMET INFO:     device              :
# COMET INFO:     entity              : None
# COMET INFO:     evolve              : None
# COMET INFO:     exist_ok            : False
# COMET INFO:     fl_gamma            : 0.0
# COMET INFO:     fliplr              : 0.5
# COMET INFO:     flipud              : 0.0
# COMET INFO:     freeze              : [0]
# COMET INFO:     hsv_h               : 0.015
# COMET INFO:     hsv_s               : 0.7
# COMET INFO:     hsv_v               : 0.4
# COMET INFO:     hyp|anchor_t        : 4.0
# COMET INFO:     hyp|box             : 0.05
# COMET INFO:     hyp|cls             : 0.5
# COMET INFO:     hyp|cls_pw          : 1.0
# COMET INFO:     hyp|copy_paste      : 0.0
# COMET INFO:     hyp|degrees         : 0.0
# COMET INFO:     hyp|fl_gamma        : 0.0
# COMET INFO:     hyp|fliplr          : 0.5
# COMET INFO:     hyp|flipud          : 0.0
# COMET INFO:     hyp|hsv_h           : 0.015
# COMET INFO:     hyp|hsv_s           : 0.7
# COMET INFO:     hyp|hsv_v           : 0.4
# COMET INFO:     hyp|iou_t           : 0.2
# COMET INFO:     hyp|lr0             : 0.01
# COMET INFO:     hyp|lrf             : 0.01
# COMET INFO:     hyp|mixup           : 0.0
# COMET INFO:     hyp|momentum        : 0.937
# COMET INFO:     hyp|mosaic          : 1.0
# COMET INFO:     hyp|obj             : 1.0
# COMET INFO:     hyp|obj_pw          : 1.0
# COMET INFO:     hyp|perspective     : 0.0
# COMET INFO:     hyp|scale           : 0.5
# COMET INFO:     hyp|shear           : 0.0
# COMET INFO:     hyp|translate       : 0.1
# COMET INFO:     hyp|warmup_bias_lr  : 0.1
# COMET INFO:     hyp|warmup_epochs   : 3.0
# COMET INFO:     hyp|warmup_momentum : 0.8
# COMET INFO:     hyp|weight_decay    : 0.0005
# COMET INFO:     image_weights       : False
# COMET INFO:     imgsz               : 640
# COMET INFO:     iou_t               : 0.2
# COMET INFO:     label_smoothing     : 0.0
# COMET INFO:     local_rank          : -1
# COMET INFO:     lr0                 : 0.01
# COMET INFO:     lrf                 : 0.01
# COMET INFO:     mixup               : 0.0
# COMET INFO:     momentum            : 0.937
# COMET INFO:     mosaic              : 1.0
# COMET INFO:     multi_scale         : False
# COMET INFO:     name                : exp
# COMET INFO:     noautoanchor        : False
# COMET INFO:     noplots             : False
# COMET INFO:     nosave              : False
# COMET INFO:     noval               : False
# COMET INFO:     obj                 : 1.0
# COMET INFO:     obj_pw              : 1.0
# COMET INFO:     optimizer           : SGD
# COMET INFO:     patience            : 100
# COMET INFO:     perspective         : 0.0
# COMET INFO:     project             : runs/train
# COMET INFO:     quad                : False
# COMET INFO:     rect                : False
# COMET INFO:     resume              : False
# COMET INFO:     save_dir            : runs/train/exp2
# COMET INFO:     save_period         : -1
# COMET INFO:     scale               : 0.5
# COMET INFO:     seed                : 0
# COMET INFO:     shear               : 0.0
# COMET INFO:     single_cls          : False
# COMET INFO:     sync_bn             : False
# COMET INFO:     translate           : 0.1
# COMET INFO:     upload_dataset      : False
# COMET INFO:     val_conf_threshold  : 0.001
# COMET INFO:     val_iou_threshold   : 0.6
# COMET INFO:     warmup_bias_lr      : 0.1
# COMET INFO:     warmup_epochs       : 3.0
# COMET INFO:     warmup_momentum     : 0.8
# COMET INFO:     weight_decay        : 0.0005
# COMET INFO:     workers             : 8
# COMET INFO:   Uploads:
# COMET INFO:     asset               : 13 (1.15 MB)
# COMET INFO:     confusion-matrix    : 1
# COMET INFO:     environment details : 1
# COMET INFO:     git metadata        : 1
# COMET INFO:     images              : 103
# COMET INFO:     installed packages  : 1
# COMET INFO:     model graph         : 1
# COMET INFO:     os packages         : 1
# COMET INFO:
# COMET INFO: Still saving offline stats to messages file before program termination (may take up to 120 seconds)
# COMET INFO: Starting saving the offline archive
# COMET INFO: To upload this offline experiment, run:
#     comet upload /content/yolov5/.cometml-runs/91fcc82babed4948b5b7c014272dc15f.zip

# %% [markdown]
# # 4. Visualize

# %% [markdown]
# ## Comet Logging and Visualization 🌟 NEW
#
# [Comet](https://www.comet.com/site/lp/yolov5-with-comet/?utm_source=yolov5&utm_medium=partner&utm_campaign=partner_yolov5_2022&utm_content=yolov5_colab) is now fully integrated with YOLOv5. Track and visualize model metrics in real time, save your hyperparameters, datasets, and model checkpoints, and visualize your model predictions with [Comet Custom Panels](https://www.comet.com/docs/v2/guides/comet-dashboard/code-panels/about-panels/?utm_source=yolov5&utm_medium=partner&utm_campaign=partner_yolov5_2022&utm_content=yolov5_colab)! Comet makes sure you never lose track of your work and makes it easy to share results and collaborate across teams of all sizes!
#
# Getting started is easy:
# ```shell
# pip install comet_ml  # 1. install
# export COMET_API_KEY=<Your API Key>  # 2. paste API key
# python train.py --img 640 --epochs 3 --data coco128.yaml --weights yolov5s.pt  # 3. train
# ```
# To learn more about all of the supported Comet features for this integration, check out the [Comet Tutorial](https://docs.ultralytics.com/yolov5/tutorials/comet_logging_integration). If you'd like to learn more about Comet, head over to our [documentation](https://www.comet.com/docs/v2/?utm_source=yolov5&utm_medium=partner&utm_campaign=partner_yolov5_2022&utm_content=yolov5_colab). Get started by trying out the Comet Colab Notebook:
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/drive/1RG0WOQyxlDlo5Km8GogJpIEJlg_5lyYO?usp=sharing)
#
# <a href="https://bit.ly/yolov5-readme-comet2">
# <img alt="Comet Dashboard" src="https://user-images.githubusercontent.com/26833433/202851203-164e94e1-2238-46dd-91f8-de020e9d6b41.png" width="1280"/></a>

# %% [markdown]
# ## ClearML Logging and Automation 🌟 NEW
#
# [ClearML](https://cutt.ly/yolov5-notebook-clearml) is completely integrated into YOLOv5 to track your experimentation, manage dataset versions and even remotely execute training runs. To enable ClearML (check cells above):
#
# - `pip install clearml`
# - run `clearml-init` to connect to a ClearML server (**deploy your own [open-source server](https://github.com/allegroai/clearml-server)**, or use our [free hosted server](https://cutt.ly/yolov5-notebook-clearml))
#
# You'll get all the great expected features from an experiment manager: live updates, model upload, experiment comparison etc. but ClearML also tracks uncommitted changes and installed packages for example. Thanks to that ClearML Tasks (which is what we call experiments) are also reproducible on different machines! With only 1 extra line, we can schedule a YOLOv5 training task on a queue to be executed by any number of ClearML Agents (workers).
#
# You can use ClearML Data to version your dataset and then pass it to YOLOv5 simply using its unique ID. This will help you keep track of your data without adding extra hassle. Explore the [ClearML Tutorial](https://docs.ultralytics.com/yolov5/tutorials/clearml_logging_integration) for details!
#
# <a href="https://cutt.ly/yolov5-notebook-clearml">
# <img alt="ClearML Experiment Management UI" src="https://github.com/thepycoder/clearml_screenshots/raw/main/scalars.jpg" width="1280"/></a>

# %% [markdown]
# ## Local Logging
#
# Training results are automatically logged with [Tensorboard](https://www.tensorflow.org/tensorboard) and [CSV](https://github.com/ultralytics/yolov5/pull/4148) loggers to `runs/train`, with a new experiment directory created for each new training as `runs/train/exp2`, `runs/train/exp3`, etc.
#
# This directory contains train and val statistics, mosaics, labels, predictions and augmentated mosaics, as well as metrics and charts including precision-recall (PR) curves and confusion matrices.
#
# <img alt="Local logging results" src="https://user-images.githubusercontent.com/26833433/183222430-e1abd1b7-782c-4cde-b04d-ad52926bf818.jpg" width="1280"/>

# %% [markdown]
# # Environments
#
# YOLOv5 may be run in any of the following up-to-date verified environments (with all dependencies including [CUDA](https://developer.nvidia.com/cuda)/[CUDNN](https://developer.nvidia.com/cudnn), [Python](https://www.python.org/) and [PyTorch](https://pytorch.org/) preinstalled):
#
# - **Notebooks** with free GPU: <a href="https://bit.ly/yolov5-paperspace-notebook"><img src="https://assets.paperspace.io/img/gradient-badge.svg" alt="Run on Gradient"></a> <a href="https://colab.research.google.com/github/ultralytics/yolov5/blob/master/tutorial.ipynb"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"></a> <a href="https://www.kaggle.com/ultralytics/yolov5"><img src="https://kaggle.com/static/images/open-in-kaggle.svg" alt="Open In Kaggle"></a>
# - **Google Cloud** Deep Learning VM. See [GCP Quickstart Guide](https://docs.ultralytics.com/yolov5/environments/google_cloud_quickstart_tutorial/)
# - **Amazon** Deep Learning AMI. See [AWS Quickstart Guide](https://docs.ultralytics.com/yolov5/environments/aws_quickstart_tutorial/)
# - **Docker Image**. See [Docker Quickstart Guide](https://docs.ultralytics.com/yolov5/environments/docker_image_quickstart_tutorial/) <a href="https://hub.docker.com/r/ultralytics/yolov5"><img src="https://img.shields.io/docker/pulls/ultralytics/yolov5?logo=docker" alt="Docker Pulls"></a>

# %% [markdown]
# # Status
#
# ![YOLOv5 CI](https://github.com/ultralytics/yolov5/actions/workflows/ci-testing.yml/badge.svg)
#
# If this badge is green, all [YOLOv5 GitHub Actions](https://github.com/ultralytics/yolov5/actions) Continuous Integration (CI) tests are currently passing. CI tests verify correct operation of YOLOv5 training ([train.py](https://github.com/ultralytics/yolov5/blob/master/train.py)), testing ([val.py](https://github.com/ultralytics/yolov5/blob/master/val.py)), inference ([detect.py](https://github.com/ultralytics/yolov5/blob/master/detect.py)) and export ([export.py](https://github.com/ultralytics/yolov5/blob/master/export.py)) on macOS, Windows, and Ubuntu every 24 hours and on every commit.

# %% [markdown]
# # Appendix
#
# Additional content below.

# %%
# YOLOv5 PyTorch HUB Inference (DetectionModels only)
import torch

model = torch.hub.load('ultralytics/yolov5', 'yolov5s', force_reload=True, trust_repo=True)  # or yolov5n - yolov5x6 or custom
im = 'https://ultralytics.com/images/zidane.jpg'  # file, Path, PIL.Image, OpenCV, nparray, list
results = model(im)  # inference
results.print()  # or .show(), .save(), .crop(), .pandas(), etc.
